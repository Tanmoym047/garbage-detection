# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanmoym047/garbage-detection/blob/main/garbage_resnet101_epoch50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Working dir
import os, pathlib, sys, random, numpy as np, tensorflow as tf
WORK_DIR = '/content/garbage_project'
os.makedirs(WORK_DIR, exist_ok=True)
# %cd $WORK_DIR
# Out:
# Mounted at /content/drive
# /content/garbage_project

# %%
print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))

# (Optional) speed opts — safe on most Colab runtimes
try:
    tf.config.optimizer.set_jit(True)   # XLA
except Exception as e:
    print("XLA not enabled:", e)
try:
    from tensorflow.keras.mixed_precision import set_global_policy
    set_global_policy("mixed_float16")  # automatic loss scaling on GPU
    print("Mixed precision enabled.")
except Exception as e:
    print("Mixed precision not enabled:", e)
# Out:
# TensorFlow: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Mixed precision enabled.

# %%
# =========================
# Colab cell 2: Point to dataset dir
# =========================
from pathlib import Path
from PIL import Image, UnidentifiedImageError
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt

# If using Kaggle: auto-discover class root
def find_class_root(base: Path, target_classes):
    targets = set(c.lower() for c in target_classes)
    for p in [base] + list(base.rglob("*")):
        if p.is_dir():
            subs = [d.name.lower() for d in p.iterdir() if d.is_dir()]
            if len(set(subs) & targets) >= 9:
                return p
    return base

TARGET_CLASSES = ["battery","biological","cardboard","clothes","glass","metal","paper","plastic","shoes","trash"]
ALLOWED_EXTS   = {".jpg",".jpeg",".png",".bmp",".webp",".jfif"}

    # 👇 change this to your Drive dataset folder if not using Kaggle
DATA_DIR = Path('/content/drive/MyDrive/garbage-dataset')


# Enumerate files, filter non-images & corrupts
all_rows, bad_files = [], []
for cls_dir in sorted([d for d in DATA_DIR.iterdir() if d.is_dir()]):
    cname = cls_dir.name.lower()
    if cname not in [c.lower() for c in TARGET_CLASSES]:
        continue
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in ALLOWED_EXTS:
            try:
                with Image.open(f) as im: im.verify()
                all_rows.append({"filepath": str(f), "label": cls_dir.name})
            except (UnidentifiedImageError, OSError, ValueError):
                bad_files.append(str(f))
        elif f.is_file():
            bad_files.append(str(f))

df_all = pd.DataFrame(all_rows)
print("Total valid images:", len(df_all), " | Skipped bad/non-images:", len(bad_files))

# Class list & counts
classes = sorted(df_all['label'].unique().tolist())
print("Classes:", classes)
cnt = df_all['label'].value_counts().loc[classes]
cnt.plot(kind="bar", figsize=(10,3), title="Class Distribution — Full Dataset")
plt.xticks(rotation=45); plt.tight_layout(); plt.show()
# Out:
# Total valid images: 19776  | Skipped bad/non-images: 0
# Classes: ['battery', 'biological', 'cardboard', 'clothes', 'glass', 'metal', 'paper', 'plastic', 'shoes', 'trash']

# %%
# =========================
# Colab cell 3: Stratified 80/10/10 split
# =========================
from sklearn.model_selection import train_test_split
import os

SEED = 42
train_df, temp_df = train_test_split(df_all, test_size=0.20, stratify=df_all['label'], random_state=SEED)
val_df,   test_df = train_test_split(temp_df, test_size=0.50, stratify=temp_df['label'], random_state=SEED)

print("Train:", train_df.shape, " Val:", val_df.shape, " Test:", test_df.shape)

# Save CSVs (reproducibility)
os.makedirs("splits", exist_ok=True)
train_df.to_csv("splits/train.csv", index=False)
val_df.to_csv("splits/val.csv", index=False)
test_df.to_csv("splits/test.csv", index=False)

# Class distribution in each split
fig, axes = plt.subplots(1,3, figsize=(16,4), sharey=True)
for ax, df, title in zip(axes, [train_df,val_df,test_df], ["Train","Val","Test"]):
    counts = df['label'].value_counts().loc[classes]
    counts.plot(kind="bar", ax=ax, title=title)
    ax.tick_params(axis='x', rotation=60)
plt.tight_layout(); plt.show()

print("Saved splits to ./splits/ (include in paper supplementary).")
# Out:
# Train: (15820, 2)  Val: (1978, 2)  Test: (1978, 2)
# Saved splits to ./splits/ (include in paper supplementary).

# %%
# =========================
# Colab cell 4: tf.data pipelines
# =========================
import tensorflow as tf
import numpy as np # Added import for numpy
AUTOTUNE = tf.data.AUTOTUNE
IMG_SIZE = 224
BATCH_SIZE = 32

# Label mapping
class_to_index = {c:i for i,c in enumerate(classes)}
index_to_class = {i:c for c,i in class_to_index.items()}

def df_to_dataset(df, shuffle=True, augment=False, cache=False):
    paths  = df['filepath'].values
    labels = df['label'].map(class_to_index).astype(np.int32).values
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    if shuffle:
        ds = ds.shuffle(min(len(paths), 4000), seed=SEED, reshuffle_each_iteration=True)
    def _load(path, label):
        img_b = tf.io.read_file(path)
        img   = tf.io.decode_image(img_b, channels=3, expand_animations=False)   # force RGB
        img.set_shape([None, None, 3])
        img   = tf.image.resize(img, [IMG_SIZE, IMG_SIZE], method="bilinear")
        img   = tf.cast(img, tf.float32)  # keep 0..255; model preprocess will scale
        return img, label
    ds = ds.map(_load, num_parallel_calls=AUTOTUNE)

    # Augment (train only): safe, fast ops
    aug = tf.keras.Sequential([
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.08),
        tf.keras.layers.RandomZoom(0.10),
        tf.keras.layers.RandomContrast(0.10),
    ], name="augment")
    def _aug(x,y):
        # brightness jitter in [0..255]
        x = tf.image.random_brightness(x, max_delta=20.0)
        x = tf.clip_by_value(x, 0.0, 255.0)
        x = aug(x, training=True)
        return x, y
    if augment:
        ds = ds.map(_aug, num_parallel_calls=AUTOTUNE)

    ds = ds.batch(BATCH_SIZE, drop_remainder=False)
    if cache: ds = ds.cache()
    ds = ds.prefetch(AUTOTUNE)
    try:
        ds = ds.apply(tf.data.experimental.ignore_errors())
    except: pass
    return ds

train_ds = df_to_dataset(train_df, shuffle=True,  augment=True,  cache=False)
val_ds   = df_to_dataset(val_df,   shuffle=False, augment=False, cache=False)
test_ds  = df_to_dataset(test_df,  shuffle=False, augment=False, cache=False)

for imgs, labs in train_ds.take(1):
    print("Sanity batch:", imgs.shape, labs.shape, imgs.dtype)
# Out:
# WARNING:tensorflow:From /tmp/ipython-input-1483026606.py:49: ignore_errors (from tensorflow.python.data.experimental.ops.error_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.ignore_errors` instead.
# Sanity batch: (32, 224, 224, 3) (32,) <dtype: 'float16'>

# %%
# =========================
# Colab cell 5: Class weights
# =========================
from sklearn.utils.class_weight import compute_class_weight
y_train = train_df['label'].map(class_to_index).values
cw = compute_class_weight(class_weight='balanced',
                          classes=np.arange(len(classes)),
                          y=y_train)
CLASS_WEIGHTS = {i: float(w) for i,w in enumerate(cw)}
print("Class weights:", {index_to_class[i]: round(w,3) for i,w in CLASS_WEIGHTS.items()})
# Out:
# Class weights: {'battery': 2.095, 'biological': 1.985, 'cardboard': 1.084, 'clothes': 0.37, 'glass': 0.646, 'metal': 1.939, 'paper': 1.177, 'plastic': 0.997, 'shoes': 1.001, 'trash': 2.087}

# %%
# =========================
# Colab cell 6: Model build (ResNet101)
# =========================
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.applications.resnet import ResNet101, preprocess_input as rn_preprocess
import numpy as np

def build_resnet101(input_shape=(IMG_SIZE, IMG_SIZE, 3), num_classes=len(classes), dropout=0.4):
    inputs = layers.Input(shape=input_shape, name="image")
    # ResNet preprocess expects 0..255 float inputs; it will BGR-shift & mean-center
    x = layers.Lambda(rn_preprocess, name="preprocess")(inputs)

    base = ResNet101(include_top=False, weights="imagenet", input_shape=input_shape)
    base.trainable = False

    x = base(x)  # keep BN frozen while base is frozen
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout)(x)
    # Force float32 on the last layer for mixed precision stability
    outputs = layers.Dense(num_classes, activation="softmax", dtype="float32")(x)

    model = models.Model(inputs, outputs, name="ResNet101_Garbage")
    # convenient handles for fine-tuning later
    model._base = base
    model._unfreeze_k = 50  # unfreeze the top ~50 layers during fine-tuning (tweak if needed)

    model.summary(line_length=110)
    trainable = np.sum([np.prod(v.shape) for v in model.trainable_weights])
    nontrain  = np.sum([np.prod(v.shape) for v in model.non_trainable_weights])
    print(f"Trainable params: {trainable:,} | Non-trainable: {nontrain:,}")
    return model

model = build_resnet101()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "ResNet101_Garbage"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                                   ┃ Output Shape                        ┃             Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)                             │ (None, 224, 224, 3)                 │                   0 │
# ├────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┤
# │ preprocess (Lambda)                            │ (None, 224, 224, 3)                 │                   0 │
# ├────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┤
# │ resnet101 (Functional)                         │ (None, 7, 7, 2048)                  │          42,658,176 │
# ├────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┤
# │ global_average_pooling2d                       │ (None, 2048)                        │                   0 │
# │ (GlobalAveragePooling2D)                       │                                     │                     │
# ├────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┤
# │ dropout (Dropout)                              │ (None, 2048)                        │                   0 │
# ├────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┤
# │ dense (Dense)                                  │ (None, 10)                          │              20,490 │
# └────────────────────────────────────────────────┴─────────────────────────────────────┴─────────────────────┘
#  Total params: 42,678,666 (162.81 MB)
#  Trainable params: 20,490 (80.04 KB)
#  Non-trainable params: 42,658,176 (162.73 MB)
# Trainable params: 20,490 | Non-trainable: 42,658,176

# %%
# =========================
# Colab cell 7: Stage A training (head only) — 10 epochs
# =========================
import time
import tensorflow as tf

class EpochTimer(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None): self.times=[]
    def on_epoch_begin(self, epoch, logs=None): self._t=time.time()
    def on_epoch_end(self, epoch, logs=None): self.times.append(time.time()-self._t)

EPOCHS_STAGE1 = 10  # head-only warmup
timerA = EpochTimer()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

cbA = [
    tf.keras.callbacks.ModelCheckpoint(
        "resnet101_stage1.keras", monitor="val_loss", save_best_only=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=2, min_lr=1e-7, verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=5, restore_best_weights=True, verbose=1
    ),
    timerA
]

histA = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_STAGE1,
    class_weight=CLASS_WEIGHTS,
    callbacks=cbA,
    verbose=1
)
# Out:
# Epoch 1/10
#     493/Unknown 319s 602ms/step - accuracy: 0.9145 - loss: 0.2819
# Epoch 1: val_loss improved from inf to 0.25438, saving model to resnet101_stage1.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 342s 648ms/step - accuracy: 0.9145 - loss: 0.2819 - val_accuracy: 0.9332 - val_loss: 0.2544 - learning_rate: 0.0010
# Epoch 2/10
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.9239 - loss: 0.2535
# Epoch 2: val_loss improved from 0.25438 to 0.22271, saving model to resnet101_stage1.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 314s 637ms/step - accuracy: 0.9239 - loss: 0.2535 - val_accuracy: 0.9430 - val_loss: 0.2227 - learning_rate: 0.0010
# Epoch 3/10
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.9216 - loss: 0.2490
# Epoch 3: val_loss did not improve from 0.22271
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 320s 633ms/step - accuracy: 0.9216 - loss: 0.2491 - val_accuracy: 0.9383 - val_loss: 0.2299 - learning_rate: 0.0010
# Epoch 4/10
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - accuracy: 0.9273 - loss: 0.2518
# Epoch 4: val_loss improved from 0.22271 to 0.19976, saving model to resnet101_stage1.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 306s 620ms/step - accuracy: 0.9273 - loss: 0.2518 - val_accuracy: 0.9383 - val_loss: 0.1998 - learning_rate: 0.0010
# Epoch 5/10
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.9286 - loss: 0.2422
# Epoch 5: val_loss did not improve from 0.19976
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 302s 612ms/step - accuracy: 0.9286 - loss: 0.2422 - val_accuracy: 0.9430 - val_loss: 0.2255 - learning_rate: 0.0010
# Epoch 6/10
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.9205 - loss: 0.2644
# Epoch 6: val_loss did not improve from 0.19976
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 301s 611ms/step - accuracy: 0.9205 - loss: 0.2643 - val_accuracy: 0.9440 - val_loss: 0.2179 - learning_rate: 0.0010
# Epoch 7/10
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.9348 - loss: 0.2126
# Epoch 7: val_loss did not improve from 0.19976
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 302s 612ms/step - accuracy: 0.9348 - loss: 0.2126 - val_accuracy: 0.9445 - val_loss: 0.2114 - learning_rate: 5.0000e-04
# Epoch 8/10
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.9355 - loss: 0.2164
# Epoch 8: val_loss did not improve from 0.19976
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 302s 612ms/step - accuracy: 0.9355 - loss: 0.2164 - val_accuracy: 0.9491 - val_loss: 0.2086 - learning_rate: 5.0000e-04
# Epoch 9/10
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 600ms/step - accuracy: 0.9408 - loss: 0.1891
# Epoch 9: val_loss did not improve from 0.19976
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 304s 616ms/step - accuracy: 0.9408 - loss: 0.1891 - val_accuracy: 0.9471 - val_loss: 0.2019 - learning_rate: 2.5000e-04
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.

# %%
# =========================
# Colab cell 8: Stage B fine-tuning (top layers) — 40 epochs
# =========================
# Unfreeze the top-k layers for fine-tuning
k = getattr(model, "_unfreeze_k", 50)
model._base.trainable = True
for layer in model._base.layers[:-k]:
    layer.trainable = False
for layer in model._base.layers[-k:]:
    layer.trainable = True

EPOCHS_STAGE2 = 40
timerB = EpochTimer()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

cbB = [
    tf.keras.callbacks.ModelCheckpoint(
        "resnet101_finetuned.keras", monitor="val_loss", save_best_only=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=3, min_lr=1e-7, verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=8, restore_best_weights=True, verbose=1
    ),
    timerB
]

histB = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_STAGE2,
    class_weight=CLASS_WEIGHTS,
    callbacks=cbB,
    verbose=1
)

# Save final model after fine-tuning
model.save("final_resnet101.keras")
print("Saved final_resnet101.keras")
# Out:
# Epoch 1/40
#     493/Unknown 365s 654ms/step - accuracy: 0.9168 - loss: 0.3012
# Epoch 1: val_loss improved from inf to 0.20003, saving model to resnet101_finetuned.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 393s 709ms/step - accuracy: 0.9168 - loss: 0.3011 - val_accuracy: 0.9450 - val_loss: 0.2000 - learning_rate: 1.0000e-05
# Epoch 2/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 620ms/step - accuracy: 0.9382 - loss: 0.1852
# Epoch 2: val_loss improved from 0.20003 to 0.17645, saving model to resnet101_finetuned.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 321s 650ms/step - accuracy: 0.9382 - loss: 0.1852 - val_accuracy: 0.9491 - val_loss: 0.1764 - learning_rate: 1.0000e-05
# Epoch 3/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 620ms/step - accuracy: 0.9485 - loss: 0.1550
# Epoch 3: val_loss improved from 0.17645 to 0.16779, saving model to resnet101_finetuned.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 319s 645ms/step - accuracy: 0.9485 - loss: 0.1550 - val_accuracy: 0.9522 - val_loss: 0.1678 - learning_rate: 1.0000e-05
# Epoch 4/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 615ms/step - accuracy: 0.9601 - loss: 0.1188
# Epoch 4: val_loss improved from 0.16779 to 0.16189, saving model to resnet101_finetuned.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 318s 644ms/step - accuracy: 0.9601 - loss: 0.1188 - val_accuracy: 0.9548 - val_loss: 0.1619 - learning_rate: 1.0000e-05
# Epoch 5/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 623ms/step - accuracy: 0.9645 - loss: 0.1035
# Epoch 5: val_loss improved from 0.16189 to 0.16176, saving model to resnet101_finetuned.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 330s 669ms/step - accuracy: 0.9645 - loss: 0.1035 - val_accuracy: 0.9573 - val_loss: 0.1618 - learning_rate: 1.0000e-05
# Epoch 6/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 620ms/step - accuracy: 0.9695 - loss: 0.0855
# Epoch 6: val_loss improved from 0.16176 to 0.15666, saving model to resnet101_finetuned.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 319s 646ms/step - accuracy: 0.9695 - loss: 0.0855 - val_accuracy: 0.9584 - val_loss: 0.1567 - learning_rate: 1.0000e-05
# Epoch 7/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 620ms/step - accuracy: 0.9752 - loss: 0.0671
# Epoch 7: val_loss improved from 0.15666 to 0.15466, saving model to resnet101_finetuned.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 329s 666ms/step - accuracy: 0.9752 - loss: 0.0671 - val_accuracy: 0.9599 - val_loss: 0.1547 - learning_rate: 1.0000e-05
# Epoch 8/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 616ms/step - accuracy: 0.9788 - loss: 0.0576
# Epoch 8: val_loss improved from 0.15466 to 0.15202, saving model to resnet101_finetuned.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 332s 672ms/step - accuracy: 0.9788 - loss: 0.0576 - val_accuracy: 0.9584 - val_loss: 0.1520 - learning_rate: 1.0000e-05
# Epoch 9/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 620ms/step - accuracy: 0.9778 - loss: 0.0618
# Epoch 9: val_loss improved from 0.15202 to 0.14567, saving model to resnet101_finetuned.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 328s 665ms/step - accuracy: 0.9778 - loss: 0.0618 - val_accuracy: 0.9625 - val_loss: 0.1457 - learning_rate: 1.0000e-05
# Epoch 10/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 617ms/step - accuracy: 0.9832 - loss: 0.0464
# Epoch 10: val_loss did not improve from 0.14567
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 313s 634ms/step - accuracy: 0.9832 - loss: 0.0464 - val_accuracy: 0.9599 - val_loss: 0.1521 - learning_rate: 1.0000e-05
# Epoch 11/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 617ms/step - accuracy: 0.9871 - loss: 0.0371
# Epoch 11: val_loss improved from 0.14567 to 0.14508, saving model to resnet101_finetuned.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 328s 647ms/step - accuracy: 0.9871 - loss: 0.0371 - val_accuracy: 0.9620 - val_loss: 0.1451 - learning_rate: 1.0000e-05
# Epoch 12/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 615ms/step - accuracy: 0.9891 - loss: 0.0308
# Epoch 12: val_loss improved from 0.14508 to 0.14336, saving model to resnet101_finetuned.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 329s 668ms/step - accuracy: 0.9891 - loss: 0.0308 - val_accuracy: 0.9625 - val_loss: 0.1434 - learning_rate: 1.0000e-05
# Epoch 13/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 618ms/step - accuracy: 0.9881 - loss: 0.0323
# Epoch 13: val_loss did not improve from 0.14336
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 313s 634ms/step - accuracy: 0.9881 - loss: 0.0322 - val_accuracy: 0.9640 - val_loss: 0.1497 - learning_rate: 1.0000e-05
# Epoch 14/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 618ms/step - accuracy: 0.9901 - loss: 0.0322
# Epoch 14: val_loss did not improve from 0.14336
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 313s 635ms/step - accuracy: 0.9901 - loss: 0.0322 - val_accuracy: 0.9635 - val_loss: 0.1546 - learning_rate: 1.0000e-05
# Epoch 15/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 618ms/step - accuracy: 0.9906 - loss: 0.0230
# Epoch 15: val_loss did not improve from 0.14336
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 313s 635ms/step - accuracy: 0.9906 - loss: 0.0230 - val_accuracy: 0.9635 - val_loss: 0.1476 - learning_rate: 1.0000e-05
# Epoch 16/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 614ms/step - accuracy: 0.9922 - loss: 0.0234
# Epoch 16: val_loss did not improve from 0.14336
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 312s 631ms/step - accuracy: 0.9923 - loss: 0.0234 - val_accuracy: 0.9645 - val_loss: 0.1442 - learning_rate: 5.0000e-06
# Epoch 17/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.9932 - loss: 0.0197
# Epoch 17: val_loss did not improve from 0.14336
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 311s 631ms/step - accuracy: 0.9932 - loss: 0.0196 - val_accuracy: 0.9630 - val_loss: 0.1523 - learning_rate: 5.0000e-06
# Epoch 18/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 616ms/step - accuracy: 0.9941 - loss: 0.0169
# Epoch 18: val_loss did not improve from 0.14336
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 367s 744ms/step - accuracy: 0.9941 - loss: 0.0169 - val_accuracy: 0.9640 - val_loss: 0.1499 - learning_rate: 5.0000e-06
# Epoch 19/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 623ms/step - accuracy: 0.9948 - loss: 0.0160
# Epoch 19: val_loss did not improve from 0.14336
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 316s 640ms/step - accuracy: 0.9948 - loss: 0.0160 - val_accuracy: 0.9651 - val_loss: 0.1507 - learning_rate: 2.5000e-06
# Epoch 20/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - accuracy: 0.9960 - loss: 0.0116
# Epoch 20: val_loss did not improve from 0.14336
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 316s 639ms/step - accuracy: 0.9960 - loss: 0.0117 - val_accuracy: 0.9651 - val_loss: 0.1506 - learning_rate: 2.5000e-06
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Saved final_resnet101.keras

# %%
# =========================
# Colab cell 9: Evaluation
# =========================
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# Inference on test
y_true, y_pred = [], []
for x_batch, y_batch in test_ds:
    preds = model.predict(x_batch, verbose=0)
    y_pred.extend(np.argmax(preds, axis=1).tolist())
    y_true.extend(y_batch.numpy().tolist())

y_true = np.array(y_true); y_pred = np.array(y_pred)
acc = accuracy_score(y_true, y_pred)
prec, rec, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="macro", zero_division=0)

print(f"\nTest Accuracy: {acc:.4f}  |  Macro-Precision: {prec:.4f}  Macro-Recall: {rec:.4f}  Macro-F1: {f1:.4f}\n")
print(classification_report(y_true, y_pred, target_names=classes, digits=4))

# Confusion matrix (normalized for readability)
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(9,7))
sns.heatmap(cm, cmap="Blues", xticklabels=classes, yticklabels=classes, cbar=True)
plt.title("Confusion Matrix — Test"); plt.xlabel("Predicted"); plt.ylabel("True"); plt.tight_layout(); plt.show()

# Per-class metrics CSV (for the paper)
p_i, r_i, f1_i, sup_i = precision_recall_fscore_support(y_true, y_pred, labels=range(len(classes)), zero_division=0)
df_metrics = pd.DataFrame({"class": classes, "precision": p_i, "recall": r_i, "f1": f1_i, "support": sup_i})
df_metrics.to_csv("per_class_metrics.csv", index=False); df_metrics.head()

# Time per epoch & model size
def path_size_mb(path):
    import os
    if os.path.isfile(path): return os.path.getsize(path)/(1024*1024)
    total=0
    for r,_,fs in os.walk(path):
        for f in fs: total += os.path.getsize(os.path.join(r,f))
    return total/(1024*1024)

avg_time_epoch = float(np.mean(timerA.times + timerB.times)) if (timerA.times or timerB.times) else np.nan
print(f"Avg time/epoch (approx): {avg_time_epoch:.2f}s")
print("Model size:", f"{path_size_mb('final_resnet101.keras'):.2f} MB")
# Out:
# Test Accuracy: 0.9666  |  Macro-Precision: 0.9591  Macro-Recall: 0.9609  Macro-F1: 0.9598
#
#               precision    recall  f1-score   support
#
#      battery     1.0000    0.9684    0.9840        95
#   biological     0.9900    0.9900    0.9900       100
#    cardboard     0.9617    0.9670    0.9644       182
#      clothes     0.9888    0.9906    0.9897       534
#        glass     0.9674    0.9706    0.9690       306
#        metal     0.9231    0.9412    0.9320       102
#        paper     0.9405    0.9405    0.9405       168
#      plastic     0.9536    0.9296    0.9415       199
#        shoes     0.9845    0.9646    0.9745       198
#        trash     0.8812    0.9468    0.9128        94
#
#     accuracy                         0.9666      1978
#    macro avg     0.9591    0.9609    0.9598      1978
# weighted avg     0.9670    0.9666    0.9667      1978
# Avg time/epoch (approx): 321.04s
# Model size: 423.07 MB
